# %%
# download dataset
link = 'http://host.robots.ox.ac.uk/pascal/VOC/voc2008/VOCtrainval_14-Jul-2008.tar'
# !wget $link

# %%
# extract dataset ---> /kaggle/working
import os
os.makedirs('dataset', exist_ok=True)
path = '/kaggle/working/VOCtrainval_14-Jul-2008.tar'
# !tar -xf $path -C /kaggle/working

# delete the downloaded .tar file
# !rm $path
